# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bids = pd.read_csv("E:\\ML\\bids.csv",index_col='bid_id', nrows=1000)

# %%
bids
# Out:
#                                     bidder_id auction     merchandise  \
# bid_id
# 0       8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr         jewelry
# 1       668d393e858e8126275433046bbd35c6tywop   aeqok       furniture
# 2       aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e      home goods
# 3       3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix         jewelry
# 4       8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix         jewelry
# ...                                       ...     ...             ...
# 995     ef40c29a478ca16687a76bc405097bbagamph   zfls2         jewelry
# 996     802e5f110cb22b03ca16f8c437a9ae59a0j5x   giskf       computers
# 997     a58ace8b671a7531c88814bc86b2a34cf0crb   z6j8b  sporting goods
# 998     668d393e858e8126275433046bbd35c6tywop   1rc8d       furniture
# 999     8b43632b2ac250c4dad3568efa29d22ai6egs   za22o         jewelry
#
#           device              time country              ip              url
# bid_id
# ...

# %%
bidder = pd.read_csv("E:\\ML\\train.csv",index_col='bidder_id')
bidder
# Out:
#                                                              payment_account  \
# bidder_id
# 91a3c57b13234af24875c56fb7e2b2f4rb56a  a3d2de7675556553a5f08e4c88d2c228754av
# 624f258b49e77713fc34034560f93fb3hu3jo  a3d2de7675556553a5f08e4c88d2c228v1sga
# 1c5f4fc669099bfbfac515cd26997bd12ruaj  a3d2de7675556553a5f08e4c88d2c2280cybl
# 4bee9aba2abda51bf43d639013d6efe12iycd  51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4ab12bc61c82ddd9c2d65e60555808acqgos1  a3d2de7675556553a5f08e4c88d2c22857ddh
# ...                                                                      ...
# 8c412ae875b672f18073d643c74f9f0clzbyw  bb154a48f536bdf27337eec09c8f39ba9cfn2
# faaa98763b59ed5f02836d4bd682035bfhujq  a3d2de7675556553a5f08e4c88d2c228xldm2
# 953e01bab9ac8786b4bfc77d183732bbqw6ng  58f6287595825798e843d59d5846067bej0bk
# c8cf68aa6abce25325dfdad4a98fd890ap57f  a3d2de7675556553a5f08e4c88d2c228yinlc
# c5c8a28a166913512f5bffa6a49788c5b0uaa  4c1b5a1bf5f64574ac61109323d9340ednwhs
#
# ...

# %%
data = bids.join(other=bidder, on='bidder_id', how='inner')
data
# Out:
#                                     bidder_id auction     merchandise  \
# bid_id
# 1       668d393e858e8126275433046bbd35c6tywop   aeqok       furniture
# 25      668d393e858e8126275433046bbd35c6tywop   38v0a       furniture
# 39      668d393e858e8126275433046bbd35c6tywop   aeqok       furniture
# 42      668d393e858e8126275433046bbd35c6tywop   jkyzt       furniture
# 68      668d393e858e8126275433046bbd35c6tywop   h2xrf       furniture
# ...                                       ...     ...             ...
# 969     d65c538ae39fc1a7e0677583bba5fdc6ax1et   jefix         jewelry
# 970     5920a92dc2b65e257061017a04eb5361tpa9b   55y7n      home goods
# 989     7b93ccc9d5730b561ec5fa7f4bd48c04qudf1   1sgd8         jewelry
# 992     e0413f338c43c9d55ba53612d2068f65t4gs6   g26sr         jewelry
# 994     86e50263881b0d382b55777185eb648aagh1g   82uit  sporting goods
#
#           device              time country               ip              url  \
# bid_id
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 220 entries, 1 to 994
# Data columns (total 12 columns):
# bidder_id            220 non-null object
# auction              220 non-null object
# merchandise          220 non-null object
# device               220 non-null object
# time                 220 non-null int64
# country              220 non-null object
# ip                   220 non-null object
# url                  220 non-null object
# payment_account      220 non-null object
# address              220 non-null object
# robot_act_prob_lk    220 non-null float64
# outcome              220 non-null int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 22.6+ KB

# %%
data.describe(include='all')
# Out:
#                                     bidder_id auction merchandise  device  \
# count                                     220     220         220     220
# unique                                     69     131           8     116
# top     dd055846eb553ab8e953b084f2048d53bdqec   jefix      mobile  phone4
# freq                                       36      14          87      16
# mean                                      NaN     NaN         NaN     NaN
# std                                       NaN     NaN         NaN     NaN
# min                                       NaN     NaN         NaN     NaN
# 25%                                       NaN     NaN         NaN     NaN
# 50%                                       NaN     NaN         NaN     NaN
# 75%                                       NaN     NaN         NaN     NaN
# max                                       NaN     NaN         NaN     NaN
#
#                 time country            ip              url  \
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# outcome              0
# robot_act_prob_lk    0
# address              0
# payment_account      0
# url                  0
# ip                   0
# country              0
# time                 0
# device               0
# merchandise          0
# auction              0
# bidder_id            0
# dtype: int64

# %%
sns.distplot(data['time'])

# %%
data['auction'].value_counts()
sns.countplot(data['auction'])

# %%
data['device'].value_counts()
# Out:
# phone4      16
# phone48     13
# phone3       7
# phone46      6
# phone38      6
#             ..
# phone300     1
# phone162     1
# phone41      1
# phone152     1
# phone215     1
# Name: device, Length: 116, dtype: int64

# %%
merchandise = data.groupby(data['merchandise'])['bidder_id'].count()
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(merchandise, labels=merchandise.index, autopct='%1.1f%%')
ax.legend(loc=3)

# %%
import datetime
your_timestamp = 9759243157894736
date = datetime.datetime.fromtimestamp(your_timestamp / 1e6)
date
# Out:
# datetime.datetime(2279, 4, 5, 10, 22, 37, 894735)

# %%
sns.boxplot(x=data['outcome'], y=data['time'])

# %%
auctionCountByTime = data.groupby(by=['auction'])['time'].count()

auctions = data['auction'].unique()
auctions
# Out:
# array(['aeqok', '38v0a', 'jkyzt', 'h2xrf', '19fz7', 'ligr3', 'jefix',
#        'bqmsa', '55y7n', '7etdx', 'k1g7r', 'wsmh2', 'bj2ts', 'uo3lj',
#        '7msk4', 'jowkm', 'uuik1', '1rc8d', 'qtmwx', 'tuhay', 'jtxiv',
#        '165y9', '3boba', '5h9tv', '4wcmc', 'ff3lz', '78i4o', 'a1xum',
#        'ufk7p', 'f11zz', '1wdd3', '5kj2r', 'l4efs', '3o5a9', 'idfc3',
#        'yhoht', 'bstmq', 'l14ty', 'c58pw', '8539e', '8r6dz', '3fbem',
#        'dywc2', 'zfls2', 'q47xb', 'pj841', 's4gxj', 'x8imu', 'b510f',
#        '9f6xq', 'h1ko2', 'ueeox', 'k8suv', 'sfkrp', 'bvxbf', '9bgje',
#        'qtito', 'wxmie', 'nxakg', 'oge32', 'rsvsf', '1foz5', 'jhm20',
#        'nhd7f', 'hf2j8', '88xe3', 'uw3sx', '0gblu', '48olb', '3vi4t',
#        'b9h4c', '97m4q', 'uppu4', 'iikzq', 'n9b6x', 'jpxg4', 'cxcqe',
#        'sc1cr', 'k3qaa', 'ikerx', '5ukki', 'aeftx', 'pjvhl', '48dnf',
#        'a7821', 'z6j8b', 'boegs', '9qusi', 'yysd7', 'tep1m', '16g0z',
# ...

# %%
data.corr(method='spearman')
# Out:
#                        time  robot_act_prob_lk   outcome
# time               1.000000           0.086443  0.086443
# robot_act_prob_lk  0.086443           1.000000  1.000000
# outcome            0.086443           1.000000  1.000000
