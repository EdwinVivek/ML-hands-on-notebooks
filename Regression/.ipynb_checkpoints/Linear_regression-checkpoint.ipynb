# %%
import numpy as np
import os
import pandas as pd
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.nonparametric.smoothers_lowess import lowess
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import category_encoders as ce
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
insurance = pd.read_csv(os.path.abspath(os.getcwd() + os.sep + os.pardir)  + '\\data\\insurance.csv')
insurance.head()
insurance.dtypes
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance.describe
insurance.describe(include="O")
# Out:
# <bound method NDFrame.describe of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# ...

# %%
f1 = insurance["charges"] > 60000
f2 = insurance["age"] >50
insurance.where(f1 | f2).dropna().sort_values(by=['charges'], ascending=False).head()
# Out:
#        age     sex     bmi  children smoker     region      charges
# 543   54.0  female  47.410       0.0    yes  southeast  63770.42801
# 1300  45.0    male  30.360       0.0    yes  southeast  62592.87309
# 1230  52.0    male  34.485       3.0    yes  northwest  60021.39897
# 1146  60.0    male  32.800       0.0    yes  southwest  52590.82939
# 1241  64.0    male  36.960       2.0    yes  southeast  49577.66240

# %%
sns.histplot(insurance['charges'], binwidth=10000)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
#analyzing the DV
fig, ax = plt.subplots(figsize=(6,6))
ax = sns.distplot(insurance['charges'])
ax.axvline(np.mean(insurance['charges']),  ls='--', color='r', label='mean')
ax.axvline(np.median(insurance['charges']),  ls='--', color='g', label='median')
ax.legend()

#skewness & kurtosis
print("Skewness:",  stats.skew(insurance['charges']))
print("Kurtosis:",  stats.kurtosis(insurance['charges']))
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Temp\ipykernel_6504\2579379142.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(insurance['charges'])
# Skewness: 1.5141797118745743
# Kurtosis: 1.595821363956751

# %%
#Log transformation on DV
charges_norm = np.log10(insurance['charges'])
fig, ax = plt.subplots(figsize=(6,6))
ax = sns.distplot(charges_norm)
ax.axvline(np.mean(charges_norm),  ls='--', color='r', label='mean')
ax.legend()

#skewness & kurtosis
print("Skewness:",  stats.skew(charges_norm))
print("Kurtosis:",  stats.kurtosis(charges_norm))
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Temp\ipykernel_6504\913757157.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(charges_norm)
# Skewness: -0.08999648706579255
# Kurtosis: -0.6387709043691361

# %%
#check for missing values
insurance.isnull().sum().sort_values(ascending=False)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#check realtions between continuous variables
sns.pairplot(data=insurance, diag_kind='kde', corner=True)

# %%
#check for correlation between variables
corr = insurance.corr(method='pearson', numeric_only=True)
sns.heatmap(corr, cmap = 'Wistia', annot=True)
# Out:
# <Axes: >

# %%
#ANOVA to check correlation with categorical variables
#h0 = variables are independent
#hA = variables are correlated
from statsmodels.formula.api import ols
lm = ols('sex ~ charges', data = insurance).fit()
table = sm.stats.anova_lm(lm)
print("P-value for 1-way ANOVA test between sex and charges is: ",table.loc['charges','PR(>F)'])
lm1 = ols('smoker ~ charges', data = insurance).fit()
table1 = sm.stats.anova_lm(lm1)
print("P-value for 1-way ANOVA test between smoker and charges is: ",table1.loc['charges','PR(>F)'])
lm2 = ols('region ~ charges', data = insurance).fit()
table2 = sm.stats.anova_lm(lm2)
print("P-value for 1-way ANOVA test between region and charges is: ",table2.loc['charges','PR(>F)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 #ANOVA to check correlation with categorical variables
#       2 #h0 = variables are independent
#       3 #hA = variables are correlated
#       4 from statsmodels.formula.api import ols
# ----> 5 lm = ols('sex ~ charges', data = insurance).fit()
#       6 table = sm.stats.anova_lm(lm)
#       7 print("P-value for 1-way ANOVA test between sex and charges is: ",table.loc['charges','PR(>F)'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\base\model.py:209, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     206 max_endog = cls._formula_max_endog
#     207 if (max_endog is not None and
#     208         endog.ndim > 1 and endog.shape[1] > max_endog):
# ...

# %%
print(insurance['children'].unique())
plt.figure(figsize=(14,4))
sns.boxplot(x='children', y='charges', hue='sex', palette='rainbow', data=insurance)
# Out:
# [0 1 3 2 5 4]
# <Axes: xlabel='children', ylabel='charges'>

# %%
f = plt.figure(figsize=(14,8))
ax = f.add_subplot(221)
sns.violinplot(x='sex', y='charges',palette='magma', data=insurance, ax=ax)
ax2 = f.add_subplot(222)
sns.violinplot(x='smoker', y='charges', data=insurance, ax=ax2)
ax3 = f.add_subplot(212)
sns.violinplot(x='region', y='charges', data=insurance, ax=ax3)
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Temp\ipykernel_6504\1436215970.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='sex', y='charges',palette='magma', data=insurance, ax=ax)
# <Axes: xlabel='sex', ylabel='charges'>
# <Axes: xlabel='smoker', ylabel='charges'>
# <Axes: xlabel='region', ylabel='charges'>

# %%
#categories to numeric
df_ins = insurance
df_ins = pd.get_dummies(df_ins, prefix_sep='_', drop_first=True)
df_ins.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400     False        True             False
# 1   18  33.770         1   1725.55230      True       False             False
# 2   28  33.000         3   4449.46200      True       False             False
# 3   33  22.705         0  21984.47061      True       False              True
# 4   32  28.880         0   3866.85520      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(insurance.iloc[:,:-1], insurance.iloc[:,-1], test_size=0.33, random_state=1)
# summarize
print('Train', x_train.shape, y_train.shape)
print('Test', x_test.shape, y_test.shape)
# Out:
# Train (896, 6) (896,)
# Test (442, 6) (442,)

# %%
# prepare input data
def prepare_inputs(X_train, X_test):
 oe = ce.OneHotEncoder()
 oe.fit(X_train)
 X_train_enc = oe.transform(X_train)
 X_test_enc = oe.transform(X_test)
 return X_train_enc, X_test_enc

prepare_inputs(x_train, x_test)
# Out:
# (      age  sex_1  sex_2     bmi  children  smoker_1  smoker_2  region_1  \
#  348    36      1      0  29.920         1         1         0         1
#  306    28      1      0  27.500         2         1         0         0
#  620    30      0      1  31.400         1         1         0         0
#  1028   54      0      1  31.600         0         1         0         0
#  1176   52      1      0  24.130         1         0         1         0
#  ...   ...    ...    ...     ...       ...       ...       ...       ...
#  715    60      0      1  28.900         0         1         0         0
#  905    26      1      0  29.355         2         1         0         0
#  1096   51      1      0  34.960         2         0         1         0
#  235    40      1      0  22.220         2         0         1         1
#  1061   57      0      1  27.940         1         1         0         1
#
#        region_2  region_3  region_4
#  348          0         0         0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
insurance_encoded = insurance
label_enc = LabelEncoder()
insurance_encoded["sex"] = label_enc.fit_transform(insurance["sex"])
insurance_encoded["smoker"] = label_enc.fit_transform(insurance["smoker"])
insurance_encoded["region"] = label_enc.fit_transform(insurance["region"])

ce_onehot =ce.OneHotEncoder(cols=['sex', 'smoker', 'region'],handle_unknown='return_nan',return_df=True,use_cat_names=True)
df_onehot = ce_onehot.fit_transform(insurance_encoded[['sex', 'smoker', 'region']])
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\category_encoders\ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\category_encoders\ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
children_encode = pd.get_dummies(df_ins['children'], prefix='children', prefix_sep='_', drop_first=True)
df_ins.drop(columns=['children'], inplace=True)
df_encode = pd.concat([df_ins, children_encode], axis=1, sort=False)
df_encode.head()
# Out:
#    age     bmi      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900  16884.92400     False        True             False
# 1   18  33.770   1725.55230      True       False             False
# 2   28  33.000   4449.46200      True       False             False
# 3   33  22.705  21984.47061      True       False              True
# 4   32  28.880   3866.85520      True       False              True
#
#    region_southeast  region_southwest  children_1  children_2  children_3  \
# 0             False              True       False       False       False
# 1              True             False        True       False       False
# 2              True             False       False       False        True
# 3             False             False       False       False       False
# 4             False             False       False       False       False
#
#    children_4  children_5
# 0       False       False
# 1       False       False
# 2       False       False
# ...

# %%
#train test split
df_encode_y = df_encode['charges']
df_encode_x = df_encode.drop(columns=['charges'])
x_train, x_test, y_train, y_test = train_test_split(df_encode_x, df_encode_y)

# %%
x_train_const = sm.add_constant(x_train) #add constant
model = sm.OLS(y_train, x_train_const.astype(float))
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     243.0
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):          5.06e-285
# Time:                        15:55:25   Log-Likelihood:                -10158.
# No. Observations:                1003   AIC:                         2.034e+04
# Df Residuals:                     990   BIC:                         2.041e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.185e+04   1163.042    -10.186      0.000   -1.41e+04   -9564.120
# ...

# %%
y_fitted = results.fittedvalues
print("MSE: %.2f" % mean_squared_error(y_train, y_fitted))
print("RMSE/Standard Error: %.2f" % mean_squared_error(y_train, y_fitted, squared=False))
print("MSE: %.2f" % mean_absolute_error(y_train, y_fitted))
# Out:
# MSE: 36638519.33
# RMSE/Standard Error: 6052.98
# MSE: 4209.86
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
#comparing results with sklearn
lreg = LinearRegression()
lreg.fit(x_train, y_train)
y_pred = lreg.predict(x_train)
evaluate(lreg, x_train, y_train, y_pred)
# Out:
# LinearRegression()
# MAE: 4209.86
# MSE: 36638519.33
# RMSE/Standard Error: 6052.98
# RMSE/Standard Error: 6052.98
# Normalized RMSE: 0.0966179692098048
# R-Squared 0.7465455654131664
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
def evaluate(model, x, y, y_fitted):
    print("MAE: %.2f" % mean_absolute_error(y, y_fitted))
    print("MSE: %.2f" % mean_squared_error(y, y_fitted))
    print("RMSE/Standard Error: %.2f" % mean_squared_error(y, y_fitted, squared=False))
    rmse = np.sqrt(mean_squared_error(y, y_fitted))
    print("RMSE/Standard Error: %.2f" % rmse)
    print("Normalized RMSE:",  rmse / (y.max() - y.min()))
    print("R-Squared", model.score(x, y))

# %%
#linearity - residual vs fitted plot
smoothed = lowess(results.resid, y_fitted)
top3 = abs(pd.Series(results.resid)).sort_values(ascending = False)[:3]
f = plt.figure(figsize=(10,4))
ax = f.add_subplot(131)
ax.set_ylabel('Residuals')
ax.set_xlabel('Fitted Values')
ax.set_title('Residuals vs. Fitted')
ax.scatter(y_fitted, results.resid, edgecolors = 'k',  facecolors = 'none')
ax.plot(smoothed[:,0],smoothed[:,1],color = 'r')
ax.plot([min(y_fitted),max(y_fitted)],[0,0],color = 'k',linestyle = ':', alpha = .3)
for i in top3.index:
    ax.annotate(i,xy=(y_fitted[i],results.resid[i]))

#Residual plot using seaborn
ax1 = f.add_subplot(132)
sns.residplot(x = y_fitted, y = results.resid, lowess=True, color='g', ax=ax1)
ax1.set_title('Residual vs Fitted using seaborn')

#Check for Linearity: Actual Vs Predicted value
ax2 = f.add_subplot(133)
sns.scatterplot(x=y_train, y= y_fitted, ax=ax2)
ax2.set_title('Check for Linearity:\n Actual Vs Predicted value')

# %%
f = plt.figure(figsize=(10,4))
ax = f.add_subplot(111)
ax.set_ylabel('Residuals')
ax.set_xlabel('Fitted Values')
ax.set_title('Residuals vs. Fitted')
ax.scatter(y_fitted, results.resid, edgecolors = 'k',  facecolors = 'none')
ax.plot(smoothed[:,0],smoothed[:,1],color = 'r')
ax.plot([min(y_fitted),max(y_fitted)],[0,0],color = 'k',linestyle = ':', alpha = .3)
for i in top3.index:
    ax.annotate(i,xy=(y_fitted[i],results.resid[i]))

# %%
#normal dist of error terms - distribution plot , qq-plot
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(121)
sns.distplot(results.resid, ax=ax)
ax.axvline(results.resid.mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual error');

ax = f.add_subplot(122)
stats.probplot(results.resid, dist="norm", plot=plt, rvalue=True)
ax.set_title('Q-Q plot');
print("Mean of residual (should be closer to 0):", np.mean(results.resid))

# %%
#homoscedasticity - scale-location plot
student_residuals = results.get_influence().resid_studentized_internal
sqrt_student_residuals = pd.Series(np.sqrt(np.abs(student_residuals)))
sqrt_student_residuals.index = pd.Series(results.resid).index
smoothed = lowess(sqrt_student_residuals, y_fitted)

fig, ax = plt.subplots()
ax.scatter(y_fitted, sqrt_student_residuals, edgecolors = 'k', facecolors = 'none')
ax.plot(smoothed[:,0],smoothed[:,1],color = 'r')
ax.set_ylabel('$\sqrt{|Studentized \ Residuals|}$')
ax.set_xlabel('Fitted Values')
ax.set_title('Scale-Location')
ax.set_ylim(0,max(sqrt_student_residuals)+0.1)

# %%
#multicollinearity - scatterplot, pairplot, heatmap
vif_data = pd.DataFrame() 
vif_data["feature"] = x_train.columns 
x_train_f = x_train.astype(float)
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(x_train_f.values, i) 
                          for i in range(len(x_train.columns))] 
  
print(vif_data)

# %%
# multicollinearity - remove highly correlated
vif_data = pd.DataFrame() 
new_x_train = x_train.loc[:, ~x_train.columns.isin(["age"])]
vif_data["feature"] = new_x_train.columns 
x_train_f = new_x_train.astype(float)
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(x_train_f.values, i) 
                          for i in range(len(new_x_train.columns))] 
  
print(vif_data)

# %%
#autocorrelation - residual vs timeplot

# %%
#outliers - residual vs levrage plot

# leverage, from statsmodels internals
leverage = results.get_influence().hat_matrix_diag 

# cook's distance, from statsmodels internals
model_cooks = results.get_influence().cooks_distance[0]

stand_resids = results.resid_pearson 

# Identify leverage points
leverage_points = np.where(leverage > np.mean(leverage) + 2 * np.std(leverage))


fig = plt.figure(figsize= (10,4))
ax1 = fig.add_subplot(111)
sns.scatterplot(x=leverage, y=stand_resids, ax=ax1) 
ax1.axhline(y=0, color='grey', linestyle='dashed') 
ax1.set_xlabel('Leverage') 
ax1.set_ylabel('Sqrt(standardized residuals)') 
ax1.set_title('Residuals vs Leverage Plot') 

# annotations
leverage_top_3 = np.flip(np.argsort(model_cooks), 0)[:3]
for i in leverage_top_3:
    fig.axes[0].annotate(i, xy=(leverage[i], stand_resids[i]))

# %%
print(model_cooks)
sort_cooks = np.argsort(model_cooks)
print(model_cooks[sort_cooks])
sort_cooks

# %%
# calculate critical d
n = len(y_train)
critical_d = 4/n
print('Critical Cooks distance:', critical_d)

# identification of potential outliers with leverage
out_d = model_cooks > critical_d

# output potential outliers with leverage
print(x_train.index[out_d], "\n", 
    model_cooks[out_d])

# %%
s = np.argsort(out_d)
x_train.index[s]

# %%
# PLot Cook's distance plot 
import statsmodels.api as sm 
sm.graphics.influence_plot(results, criterion="cooks") 
fig.tight_layout(pad=1.0)

# %%
#prediction
def score(lead_features: pd.DataFrame) -> np.ndarray:
    return lreg.predict(lead_features)

# %%
score(x_test)

# %% [markdown]
# <h2> Log Transformation on DV

# %%
#with log(DV) 
df_encode_log = df_encode.copy(deep=True)
df_encode_log['charges'] = charges_norm
df_encode_ylog = df_encode_log['charges']
df_encode_xlog = df_encode_log.drop(columns=['charges'])
xlog_train, xlog_test, ylog_train, ylog_test = train_test_split(df_encode_xlog, df_encode_ylog)

xlog_train_const = sm.add_constant(xlog_train) #add constant
model_log = sm.OLS(ylog_train, xlog_train_const.astype(float))
results_log = model_log.fit()
print(results_log.summary())

# %%
ylog_fitted = results_log.fittedvalues
evaluate(model_log, x_train, ylog_train, ylog_fitted)

# %%
fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(111)
sns.residplot(x = ylog_fitted, y = results_log.resid, lowess=True, color='g', ax=ax1)
ax1.set_title('Residual vs Fitted using seaborn - Log(DV)')

# %%
#normal dist of error terms - distribution plot , qq-plot
fig = plt.figure(figsize=(14,5))
ax = fig.add_subplot(121)
sns.distplot(results_log.resid, ax=ax)
ax.axvline(results_log.resid.mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual error - Log(DV)');

ax = fig.add_subplot(122)
stats.probplot(results_log.resid, dist="norm", plot=plt, rvalue=True)
ax.set_title('Q-Q plot');
print("Mean of residual (should be closer to 0):", np.mean(results_log.resid))

# %%
q = 0.5 # alpha or significance level
dfn = 12 # numerator degrees of freedom - (g-1)  where g is the amount of groups. 
dfd = 990 # denominator degrees of freedom - (N-g) where N is the sample size of all groups combined and g is the number of groups. 
F_critical = stats.f.ppf(q, dfn, dfd)
F_critical

# %% [markdown]
# <h2>Polymomial Regression on Data

# %%
from sklearn.preprocessing import PolynomialFeatures

# Train polynomial regression model on the whole dataset
pr = PolynomialFeatures(degree = 2)
X_poly = pr.fit_transform(x_train)
Xpoly_train_const = sm.add_constant(X_poly) #add constant
lr_2 = sm.OLS(y_train, Xpoly_train_const.astype(float))
results_poly = lr_2.fit()
print(results_poly.summary())
#lr_2 = LinearRegression()
#lr_2.fit(X_poly, y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     81.51
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):               0.00
# Time:                        15:57:17   Log-Likelihood:                -9881.6
# No. Observations:                1003   AIC:                         1.990e+04
# Df Residuals:                     935   BIC:                         2.023e+04
# Df Model:                          67
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1358.7264   4323.788     -0.314      0.753   -9844.180    7126.728
# ...

# %%
print("Input",pr.n_features_in_)
print("Ouput",pr.n_output_features_)
print("Ouput names",pr.get_feature_names_out())

# %%
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y_train)
y_pred_poly = poly_reg.predict(pr.fit_transform(x_test))
evaluate(poly_reg, pr.fit_transform(x_test), y_test, y_pred_poly)
# Out:
# LinearRegression()
# MAE: 2969.35
# MSE: 25243505.98
# RMSE/Standard Error: 5024.29
# RMSE/Standard Error: 5024.29
# Normalized RMSE: 0.08747999728633082
# R-Squared 0.8344532772562985
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
ypoly_fitted = results_poly.fittedvalues
fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(111)
sns.residplot(x = ypoly_fitted, y = results_poly.resid, lowess=True, color='g', ax=ax1)
ax1.set_title('Residual vs Fitted using seaborn - Polynomial-2')

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(fit_intercept=True, alpha=1)
ridge.fit(X_poly, y_train)
y_pred_ridge = ridge.predict(pr.fit_transform(x_test))
evaluate(ridge, pr.fit_transform(x_test), y_test, y_pred_ridge)
# Out:
# Ridge(alpha=1)
# MAE: 2940.92
# MSE: 24742734.65
# RMSE/Standard Error: 4974.21
# RMSE/Standard Error: 4974.21
# Normalized RMSE: 0.08660795287858952
# R-Squared 0.8377373319308479
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
x_range = np.linspace(x_train.min(), x_train.max())
x_values =  pr.fit_transform(x_range)
y_range_lr = lin2.intercept_+ np.sum(lin2.coef_ * x_values, axis = 1)
y_range_ridge = ridge.intercept_ + np.sum(ridge.coef_ * x_values, axis = 1)


plt.figure(figsize=(12, 8))
plt.plot(x_range, y_range_lr, c = 'blue', linewidth = 4, label = 'Linear Regression')
plt.plot(x_range, y_range_ridge, c  = 'magenta', label='Ridge Regression')
plt.scatter(x_train.iloc[:,1], y_train, s = 200, c = 'red', marker = 'x', linewidths = 1, label = "Data")
plt.xlabel('Change in water level (x)')
plt.ylabel('Water flowing out of the dam (y)')
plt.title('Polynomial Regression with Scikit Learn')
plt.legend()
plt.grid(True)

# %%
#normal dist of error terms - distribution plot , qq-plot
fig = plt.figure(figsize=(14,5))
ax = fig.add_subplot(121)
sns.distplot(results_poly.resid, ax=ax)
ax.axvline(results_poly.resid.mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual error - Log(DV)');

ax = fig.add_subplot(122)
stats.probplot(results_poly.resid, dist="norm", plot=plt, rvalue=True)
ax.set_title('Q-Q plot');
print("Mean of residual (should be closer to 0):", np.mean(results_log.resid))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
def polynomial_regression(degree):
    X_new=np.linspace(-3, 3, 100).reshape(100, 1)
    polybig_features = PolynomialFeatures(degree=degree, include_bias=False)
    std_scaler = StandardScaler()
    lin_reg = LinearRegression()
    polynomial_regression = Pipeline([
            ("poly_features", polybig_features),
            ("std_scaler", std_scaler),
            ("lin_reg", lin_reg),
        ])
    polynomial_regression.fit(X_new, y)
    X_new_poly = polybig_features.transform(X_new)
    y_newbig = polynomial_regression.predict(X_new)
    #plotting prediction line
    plt.plot(X_new, y_newbig,'r', label="Degree " + str(degree), linewidth=2)
    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-3, 3, 0, 10])
    plt.show()

# %%
#huber regression
from sklearn.linear_model import HuberRegressor
huber = HuberRegressor().fit(x_train, y_train)
huber.coef_[0] 
predict_huber = huber.predict(x_train)
resid_huber = y_train - predict_huber
evaluate(huber, x_train, y_train, predict_huber)
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 266.1438472915138
# MAE: 3446.80
# MSE: 48398666.83
# RMSE/Standard Error: 6956.92
# RMSE/Standard Error: 6956.92
# Normalized RMSE: 0.11104669750229489
# R-Squared 0.6651923450463145
# ...

# %%
#Residual plot using seaborn
f = plt.figure(figsize=(10,4))
ax = f.add_subplot(111)
sns.residplot(x = predict_huber, y = resid_huber, lowess=True, color='g', ax=ax)
ax1.set_title('Residual vs Fitted using seaborn')
fig.show()

# %% [markdown]
# <h2>Model Selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector
forwad = SequentialFeatureSelector(
ridge,
k_features=10,
forward=True,
verbose=1,
scoring="neg_mean_squared_error"
)
sf = forwad.fit(X_poly,y_train)

feat_names = list(sf.k_feature_names_)
print(feat_names)

print(sf.k_feature_idx_)
sf.k_score_
# Out:
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# ...

# %%
X_poly_df = pd.DataFrame(X_poly)
cols = np.asarray(sf.k_feature_idx_)
X_poly_reduced = X_poly_df.iloc[:,cols.tolist()]
x_test_poly =  pd.DataFrame(pr.fit_transform(x_test))
x_test_poly_reduced = x_test_poly.iloc[:,cols.tolist()]

ridge2 = Ridge(fit_intercept=True, alpha=1)
ridge2.fit(X_poly_reduced, y_train)
y_pred_ridge = ridge.predict(x_test_poly_reduced)
evaluate(ridge, x_test_poly_reduced, y_test, y_pred_ridge)
# Out:
# Ridge(alpha=1)
# MAE: 2988.94
# MSE: 24238273.73
# RMSE/Standard Error: 4923.24
# RMSE/Standard Error: 4923.24
# Normalized RMSE: 0.08572051420172001
# R-Squared 0.841045582860035
# C:\Users\EdwinVivekN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
#RFE
from sklearn.feature_selection import RFE, RFECV
rfe_mod = RFE(ridge, n_features_to_select=5, step=1) #RFECV(lin_reg, step=1, cv=5) 
myvalues=rfe_mod.fit(X_poly,y_train) #to fit
myvalues.support_#The mask of selected features.
myvalues.ranking_ #The feature ranking, such that ranking_[i] corresponds to the ranking position of the i-th feature. Selected (i.e., estimated best) features are assigned rank 1.

rankings=pd.DataFrame(myvalues.ranking_) #Make it into data frame

#Concat and name columns
ranked=pd.concat([pd.DataFrame(pr.get_feature_names_out()) ,rankings], axis=1)
ranked.columns = ["Feature", "Rank"]
ranked

#Select most important (Only 1's)
most_important = ranked.loc[ranked['Rank'] ==1] 
print(most_important)

most_important['Rank'].count()
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])
# array([87, 31, 48, 65,  1, 39, 38, 59, 19,  5, 26, 34, 27, 72, 73, 61, 54,
#        63, 50, 53, 47, 43, 64, 35, 69, 67, 57,  9, 62, 42, 52, 70, 58, 45,
#        32, 68, 66, 51,  6, 44, 55, 20, 22, 23,  3, 41,  1, 29, 16, 30, 14,
# ...

# %%
# generate an independent variable
x = np.linspace(-10, 30, 100) 
# generate a normally distributed residual 
e = np.random.normal(10, 5, 100) 
# generate ground truth 
y = 10 + 4*x + e
df = pd.DataFrame({'x':x, 'y':y}) 
df.head()
sns.regplot(x='x', y='y', data = df) 
plt.show()
